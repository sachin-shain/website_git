# %%
width , height = 19,16
w_by_h = width/height

def h_calc( w):
    return round(w /w_by_h , 0) 


def w_calc(h):
    return round(h * w_by_h , 0)

# %%
w = 864

h_calc(w)
# Out:
# 728.0

# %%
h = 727

w_calc(h)
# Out:
# 863.0

# %%
h * w_by_h
# Out:
# 864.5

# %%
l = [10/(19/16),10/(4/3) *.5,10/(4/3)]
l2 = l
s1 = l2[0]+l2[1]+l2[2]

for i in range(3):
    l2[i] = l2[i]/s1*100
    print(f"{l2[i]:.0f}")
# Out:
# 43
# 19
# 38

# %%
l2[0]
# Out:
# 8.421052631578947
